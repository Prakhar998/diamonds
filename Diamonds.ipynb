# %%
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.contrib.layers import fully_connected

# %%
dataset=pd.read_csv(r'diamonds.csv')

# %%
dataset
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 0               1   0.23      Ideal     E     SI2   61.5   55.0    326  3.95
# 1               2   0.21    Premium     E     SI1   59.8   61.0    326  3.89
# 2               3   0.23       Good     E     VS1   56.9   65.0    327  4.05
# 3               4   0.29    Premium     I     VS2   62.4   58.0    334  4.20
# 4               5   0.31       Good     J     SI2   63.3   58.0    335  4.34
# 5               6   0.24  Very Good     J    VVS2   62.8   57.0    336  3.94
# 6               7   0.24  Very Good     I    VVS1   62.3   57.0    336  3.95
# 7               8   0.26  Very Good     H     SI1   61.9   55.0    337  4.07
# 8               9   0.22       Fair     E     VS2   65.1   61.0    337  3.87
# 9              10   0.23  Very Good     H     VS1   59.4   61.0    338  4.00
# 10             11   0.30       Good     J     SI1   64.0   55.0    339  4.25
# ...

# %%
dataset=pd.concat([dataset,pd.get_dummies(dataset['cut'],prefix='cut',drop_first=True)],axis=1)
dataset=pd.concat([dataset,pd.get_dummies(dataset['color'],prefix='color',drop_first=True)],axis=1)
dataset=pd.concat([dataset,pd.get_dummies(dataset['clarity'],prefix='clarity',drop_first=True)],axis=1)

# %%
dataset.drop(['cut','color','clarity'],axis=1,inplace=True)

# %%
from sklearn.preprocessing import RobustScaler
from sklearn.model_selection import train_test_split 
tar='price'
rob=RobustScaler()
X=dataset.drop('price',axis=1)
y=dataset[tar]
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=123)

# %%
n_epoch=40
batch_size=60

# %%
X_placeholder=tf.placeholder(X_train ,shape=X_train.shape)
y_placeholder=tf.placeholder(y_train ,shape=y_train.shape)
data=tf.contrib.data.Dataset.from_tensor_slices((X_placeholder,y_placeholder))
data=data.shuffle(buffer_size=10000)
data=data.batch(batch_size)
iterator=data.make_intializer_iterator()
next_element=iterator.get_next()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/eager/execute.py in make_type(v, arg_name)
#     126   try:
# --> 127     v = dtypes.as_dtype(v).base_dtype
#     128   except TypeError:
#
# ~/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py in as_dtype(type_value)
#     687   try:
# --> 688     return _INTERN_TABLE[type_value]
#     689   except KeyError:
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __hash__(self)
#    1815         raise TypeError('{0!r} objects are mutable, thus they cannot be'
# -> 1816                         ' hashed'.format(self.__class__.__name__))
#    1817
#
# TypeError: 'DataFrame' objects are mutable, thus they cannot be hashed
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
n_inputs=X_train.shape[1]
n_hidden1=256
n_hidden2=128
n_outpts=1

# %%
from pandas

# %%
X=tf.placeholder(X_train,shape=[None,n_inputs])
y=tf.placeholder(y_train)

# %%
def nn(X_values):
    hidden1=fully_connected(X_values,n_hidden1)
    hidden2=fully_connected(n_hidden1,n_hidden2)
    hidden3=fully_connected(hidden_2,hidden_3)
    y_pred=fully_connected(hidden3,n_outputs,activation_fn=None)
    return tf.squeeze(y_pred)

# %%
y_pred=nn(X)
loss=tf.losses.mean_squared_error(labels=y,predictions=y_pred)
